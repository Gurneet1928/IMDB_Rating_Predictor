# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('data.csv',index_col=0)

# %%
df
# Out:
#                                              title  \
# 0                         The Shawshank Redemption
# 1                                    The Godfather
# 3                                  The Dark Knight
# 4    The Lord of the Rings: The Return of the King
# 5                                 Schindler's List
# ..                                             ...
# 990                                The Jungle Book
# 992                                      The Birds
# 993                           Les yeux sans visage
# 996                          From Here to Eternity
# 997                Snow White and the Seven Dwarfs
#
#                             genre  duration  rating  year  \
# 0                           Drama       142     9.3  1994
# 1                    Crime, Drama       175     9.2  1972
# 3            Action, Crime, Drama       152     9.0  2008
# 4        Action, Adventure, Drama       201     9.0  2003
# ...

# %%
df['gross'] = df['gross'].str.replace('$','')
df['gross'] = df['gross'].str.replace('M','')
df['gross'] = df['gross'].apply(pd.to_numeric)
df['gross'] = df['gross']*1000000
# Out:
# C:\Users\gurne\AppData\Local\Temp\ipykernel_17340\1359056640.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['gross'] = df['gross'].str.replace('$','')

# %%
df
# Out:
#                                              title  \
# 0                         The Shawshank Redemption
# 1                                    The Godfather
# 3                                  The Dark Knight
# 4    The Lord of the Rings: The Return of the King
# 5                                 Schindler's List
# ..                                             ...
# 990                                The Jungle Book
# 992                                      The Birds
# 993                           Les yeux sans visage
# 996                          From Here to Eternity
# 997                Snow White and the Seven Dwarfs
#
#                             genre  duration  rating  year  \
# 0                           Drama       142     9.3  1994
# 1                    Crime, Drama       175     9.2  1972
# 3            Action, Crime, Drama       152     9.0  2008
# 4        Action, Adventure, Drama       201     9.0  2003
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 743 entries, 0 to 997
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           743 non-null    object
#  1   genre           743 non-null    object
#  2   duration        743 non-null    int64
#  3   rating          743 non-null    float64
#  4   year            743 non-null    int64
#  5   director        743 non-null    object
#  6   major cast      743 non-null    object
#  7   2nd major cast  743 non-null    object
#  8   certification   661 non-null    object
#  9   gross           743 non-null    float64
#  10  votes           743 non-null    object
#  11  link            743 non-null    object
#  12  budget          743 non-null    int64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 81.3+ KB

# %%
df.nunique()
# Out:
# title             743
# genre             172
# duration          130
# rating             17
# year               97
# director          456
# major cast        518
# 2nd major cast    625
# certification      17
# gross             666
# votes             742
# link              743
# budget            325
# dtype: int64

# %%
sb.pairplot(df)

# %%
df['votes'] = df['votes'].str.replace(',','')
df['votes'] = df['votes'].apply(pd.to_numeric)

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 743 entries, 0 to 997
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           743 non-null    object
#  1   genre           743 non-null    object
#  2   duration        743 non-null    int64
#  3   rating          743 non-null    float64
#  4   year            743 non-null    int64
#  5   director        743 non-null    object
#  6   major cast      743 non-null    object
#  7   2nd major cast  743 non-null    object
#  8   certification   661 non-null    object
#  9   gross           743 non-null    float64
#  10  votes           743 non-null    int64
#  11  link            743 non-null    object
#  12  budget          743 non-null    int64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 97.4+ KB
#          duration      rating         year         gross         votes  \
# ...

# %%
sb.pairplot(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 743 entries, 0 to 997
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           743 non-null    object
#  1   genre           743 non-null    object
#  2   duration        743 non-null    int64
#  3   rating          743 non-null    float64
#  4   year            743 non-null    int64
#  5   director        743 non-null    object
#  6   major cast      743 non-null    object
#  7   2nd major cast  743 non-null    object
#  8   certification   661 non-null    object
#  9   gross           743 non-null    float64
#  10  votes           743 non-null    int64
#  11  link            743 non-null    object
#  12  budget          743 non-null    int64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 81.3+ KB

# %%
df['genre'] = df['genre'].astype('|S')
df['director'] = df['director'].astype('|S')
df['major cast'] = df['major cast'].astype('|S')
df['certification'] = df['certification'].astype('|S')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Input In [16], in <cell line: 2>()
#       1 df['genre'] = df['genre'].astype('|S')
# ----> 2 df['director'] = df['director'].astype('|S')
#       3 df['major cast'] = df['major cast'].astype('|S')
#       4 df['certification'] = df['certification'].astype('|S')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# ...

# %%
df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 743 entries, 0 to 997
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           743 non-null    object
#  1   genre           743 non-null    object
#  2   duration        743 non-null    int64
#  3   rating          743 non-null    float64
#  4   year            743 non-null    int64
#  5   director        743 non-null    object
#  6   major cast      743 non-null    object
#  7   2nd major cast  743 non-null    object
#  8   certification   743 non-null    object
#  9   gross           743 non-null    float64
#  10  votes           743 non-null    int64
#  11  link            743 non-null    object
#  12  budget          743 non-null    int64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 81.3+ KB
